# %%
#in a class function
#showfood items
#delete food we eant
#add food regadingly available


class food:
    def __init__(self,data):
        self.fooditems=data
    def showitems(self):
        for i in self.fooditems:
            print(i)  
    def lendafood(self,foodname):
        if foodname in self.fooditems:
         self.fooditems.remove(foodname)
         print("your request is done,Thank you")
        else:
         print("food is not available")
    def addafood(self,returnedfood):
        self.fooditems.append(returnedfood)
        print("food added successfully")    

class customer:
    def requestafood(self):
      print("enter the name the food you like to buy")
      self.food=input()
      return self.food
    def returnafood(self):
      print("enter the name of the food you like to give back") 
      self.food=input() 
      return self.food

# %%
f=food(["idly","vada","dosa","coffee","pongal"])
c=customer()

# %%
while True:
  print("select option")
  print("\n 1-show food \n 2-buy food \n 3.add food")
  opt=int(input())
  if opt==1:
    f.showitems()
  elif opt==2:
    requestedfood=c.requestafood()
    f.lendafood(requestedfood)  
  elif opt==3:
    returnedfood=c.returnafood()
    f.addafood(returnedfood)
# Out:
# select option
#
#  1-show food
#  2-buy food
#  3.add food
# idly
# vada
# dosa
# coffee
# pongal
# select option
#
#  1-show food
#  2-buy food
#  3.add food
# enter the name the food you like to buy
# your request is done,Thank you
# select option
#
#  1-show food
#  2-buy food
#  3.add food
# vada
# dosa
# coffee
# pongal
# select option
#
#  1-show food
#  2-buy food
#  3.add food
# enter the name of the food you like to give back
# food added successfully
# select option
#
#  1-show food
#  2-buy food
#  3.add food
# vada
# dosa
# coffee
# pongal
# pongal
# select option
#
#  1-show food
#  2-buy food
#  3.add food
# enter the name of the food you like to give back
# food added successfully
# select option
#
#  1-show food
#  2-buy food
#  3.add food
# vada
# dosa
# coffee
# pongal
# pongal
# idly
# select option
#
#  1-show food
#  2-buy food
#  3.add food
# enter the name the food you like to buy
# your request is done,Thank you
# select option
#
#  1-show food
#  2-buy food
# ...
